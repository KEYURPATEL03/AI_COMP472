# %% [markdown]
# # 2. Words as Features

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from gensim.downloader import load
import gensim
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist 
from gensim.models import Word2Vec
from nltk.tokenize import RegexpTokenizer
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Nareg
# [nltk_data]     Mouradian\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## 2.1 Processing the dataset and displaying the number of tokens

# %%
#2.1 Processing the dataset;Displayed the number of tokens in the dataset
with open("goemotions.json", "r") as data:
    file = pd.read_json(data)
    
emotion = file[1].value_counts().to_dict()
sentiment = file[2].value_counts().to_dict()

posts = file[0].tolist()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(posts)

print(f"The size of the vocabulary is {len(X.toarray()[0])}")
# Out:
# The size of the vocabulary is 30449

# %% [markdown]
# ## 2.2 Splitting the dataset

# %%
#2.2 Splitting the dataset
#get the location
emo = preprocessing.LabelEncoder()
senti = preprocessing.LabelEncoder()

#vectorizing emotions
emo = emo.fit_transform(file[1]) 
#vectorizing sentiments
senti = senti.fit_transform(file[2]) 

#now splitting the data 
X_train,X_test,Yemo_train, Yemo_test,Ysenti_train, Ysenti_test = train_test_split(X,emo,senti, test_size = 0.2, train_size=0.8)

# %% [markdown]
# # 2.3 and 2.4 Classifiers and Metrics

# %% [markdown]
# ### 2.3.2 Base-DT: Decision Tree with default parameters (Emotion)

# %%
from sklearn import tree
#2.3.2 Base DT for emotions:
baseDTCemo = tree.DecisionTreeClassifier()
baseDTCemo.fit(X_train, Yemo_train)
# Out:
# DecisionTreeClassifier()

# %%
y_emo_pred = baseDTCemo.predict(X_test)

# %% [markdown]
# ### 2.4 Base-DT: Decision Tree with default parameters (Emotion Performance)

# %%
#2.4 Performances for the emotion part (Base DT):
print("Base Decision Tree with default parameters for the emotion classification task:")
# Out:
# Base Decision Tree with default parameters for the emotion classification task:

# %%
#The confusion matrix for it:
from sklearn.metrics import confusion_matrix
print("Emotion classification task confusion matrix:")
conf_mat = confusion_matrix(Yemo_test, y_emo_pred)
from sklearn.metrics import ConfusionMatrixDisplay
cmdisp = ConfusionMatrixDisplay(conf_mat)
fig, ax = plt.subplots(figsize=(20, 20)) #suggested from stack-overflow
cmdisp.plot(ax = ax)
# Out:
# Emotion classification task confusion matrix:

# %%
#Classification Report:
from sklearn.metrics import classification_report
print(classification_report(Yemo_test, y_emo_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.56      0.47      2124
#            1       0.45      0.57      0.50      1250
#            2       0.22      0.36      0.27       982
#            3       0.15      0.21      0.17      1656
#            4       0.21      0.28      0.24      2265
#            5       0.22      0.26      0.24       700
#            6       0.23      0.29      0.26      1043
#            7       0.33      0.34      0.33      1198
#            8       0.26      0.29      0.27       459
#            9       0.15      0.17      0.16       943
#           10       0.24      0.23      0.24      1558
#           11       0.24      0.20      0.21       576
#           12       0.19      0.14      0.16       300
#           13       0.22      0.22      0.22       596
#           14       0.43      0.41      0.42       341
#           15       0.76      0.74      0.75      1360
#           16       0.18      0.15      0.16        66
#           17       0.26      0.22      0.24       849
#           18       0.54      0.51      0.52       981
#           19       0.18      0.12      0.14       138
#           20       0.50      0.43      0.46     11044
#           21       0.36      0.22      0.27       877
#           22       0.10      0.04      0.06       147
#           23       0.18      0.07      0.10       951
#           24       0.19      0.07      0.10       156
#           25       0.38      0.27      0.31       297
#           26       0.36      0.19      0.25       751
#           27       0.41      0.21      0.28       756
#
#     accuracy                           0.36     34364
#    macro avg       0.30      0.28      0.28     34364
# weighted avg       0.37      0.36      0.36     34364

# %% [markdown]
# ### 2.3.2 Base-DT: Decision Tree with default parameters (Sentiment)

# %%
from sklearn import tree
#2.3.2 Base DT for sentiment:
baseDTCsenti = tree.DecisionTreeClassifier()
baseDTCsenti.fit(X_train, Ysenti_train)
# Out:
# DecisionTreeClassifier()

# %%
y_senti_pred = baseDTCsenti.predict(X_test)

# %% [markdown]
# ### 2.4 Base-DT: Decision Tree with default parameters (Sentiment Performance)

# %%
#2.4 Performances for the sentiment part:
print("Base Decision Tree with default parameters for the sentiment classification task:")
# Out:
# Base Decision Tree with default parameters for the sentiment classification task:

# %%
#The confusion matrix for it:
from sklearn.metrics import confusion_matrix
print("Sentiment classification task confusion matrix:")
confusion_matrix(Ysenti_test, y_senti_pred)
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(baseDTCsenti, X_test, Ysenti_test)
# Out:
# Sentiment classification task confusion matrix:

# %%
#Classification Report:
from sklearn.metrics import classification_report
print(classification_report(Ysenti_test, y_senti_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.47      0.41      3948
#            1       0.50      0.59      0.54      7608
#            2       0.51      0.47      0.49     11044
#            3       0.70      0.59      0.64     11764
#
#     accuracy                           0.54     34364
#    macro avg       0.52      0.53      0.52     34364
# weighted avg       0.56      0.54      0.54     34364

# %% [markdown]
# ### 2.5 Top-DT: a better performing Decision Tree with hyperparameters (Emotion)

# %%
from sklearn import tree
#2.3.5 Top DT for emotions:
topDTCemo = tree.DecisionTreeClassifier(criterion = "entropy" ,  max_depth = 25, min_samples_split = 4)
topDTCemo.fit(X_train, Yemo_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=25, min_samples_split=4)

# %%
y_emo_pred_top = topDTCemo.predict(X_test)

# %%
#Making a parameter for the param_grid part of the GridSearchCV function:
parameters_for_the_grid_emo = {
    "criterion" : ["gini" , "entropy"] , 
    "max_depth" : [25, 50], 
    "min_samples_split" : [4 , 7 , 10]
}

# %%
from sklearn.model_selection import GridSearchCV
gSCVemo = GridSearchCV(estimator = topDTCemo, param_grid = parameters_for_the_grid_emo)
#Fitting the instance
gSCVemo.fit(X_train, Yemo_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=25,
#                                               min_samples_split=4),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [25, 50],
#                          'min_samples_split': [4, 7, 10]})

# %% [markdown]
# ### 2.4 Top-DT: Decision Tree with hyperparameters (Emotion Performance)

# %%
#2.4 Performances for the emotion part (Top DT):
print("Top Decision Tree with hyperparameters for the emotion classification task:")
# Out:
# Top Decision Tree with hyperparameters for the emotion classification task:

# %%
#The confusion matrix for it:
from sklearn.metrics import confusion_matrix
print("Emotion classification task confusion matrix:")
conf_mat_top = confusion_matrix(Yemo_test, y_emo_pred_top)
from sklearn.metrics import ConfusionMatrixDisplay
cmdisp_top = ConfusionMatrixDisplay(conf_mat_top)
fig, ax = plt.subplots(figsize=(20, 20)) #suggested from stack-overflow
cmdisp_top.plot(ax = ax)
# Out:
# Emotion classification task confusion matrix:

# %%
#Classification Report:
from sklearn.metrics import classification_report
print(classification_report(Yemo_test, y_emo_pred_top))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.29      0.35      2180
#            1       0.51      0.45      0.48      1248
#            2       0.36      0.09      0.15      1059
#            3       0.12      0.01      0.03      1712
#            4       0.13      0.01      0.02      2276
#            5       0.19      0.05      0.08       656
#            6       0.32      0.06      0.10       982
#            7       0.31      0.02      0.04      1202
#            8       0.35      0.17      0.23       433
#            9       0.08      0.01      0.01       914
#           10       0.12      0.01      0.02      1508
#           11       0.09      0.00      0.01       566
#           12       0.00      0.00      0.00       269
#           13       0.19      0.03      0.05       588
#           14       0.18      0.01      0.01       360
#           15       0.81      0.68      0.74      1383
#           16       0.17      0.01      0.03        72
#           17       0.39      0.14      0.21       867
#           18       0.64      0.50      0.56       963
#           19       0.00      0.00      0.00       158
#           20       0.38      0.91      0.54     11102
#           21       0.51      0.19      0.27       895
#           22       0.00      0.00      0.00       132
#           23       0.12      0.00      0.01       921
#           24       0.19      0.02      0.04       144
#           25       0.46      0.31      0.37       306
#           26       0.57      0.11      0.19       765
#           27       0.38      0.16      0.23       703
#
#     accuracy                           0.40     34364
#    macro avg       0.29      0.15      0.17     34364
# weighted avg       0.34      0.40      0.30     34364

# %% [markdown]
# ### 2.5 Top-DT: a better performing Decision Tree with hyperparameters (Sentiment)

# %%
from sklearn import tree
#2.3.5 Base DT for sentiments:
topDTCsenti = tree.DecisionTreeClassifier()
topDTCsenti.fit(X_train, Ysenti_train)
# Out:
# DecisionTreeClassifier()

# %%
y_senti_pred_top = topDTCsenti.predict(X_test)

# %%
#Making a parameter for the param_grid part of the GridSearchCV function:
parameters_for_the_grid_senti = {
    "criterion" : ["gini" , "entropy"] , 
    "max_depth" : [25, 50], 
    "min_samples_split" : [4 , 7 , 10]
}

# %%
from sklearn.model_selection import GridSearchCV
gSCVsenti = GridSearchCV(estimator = topDTCsenti, param_grid = parameters_for_the_grid_senti)
#Fitting the instance
gSCVsenti.fit(X_train, Ysenti_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [25, 50],
#                          'min_samples_split': [4, 7, 10]})

# %% [markdown]
# ### 2.4 Top-DT: Decision Tree with hyperparameters (Sentiment Performance)

# %%
#2.4 Performances for the emotion part (Top DT):
print("Top Decision Tree with hyperparameters for the sentiment classification task:")
# Out:
# Top Decision Tree with hyperparameters for the sentiment classification task:

# %%
#The confusion matrix for it:
from sklearn.metrics import confusion_matrix
print("Sentiment classification task confusion matrix:")
confusion_matrix(Ysenti_test, y_senti_pred_top)
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(gSCVsenti, X_test, Ysenti_test)
# Out:
# Sentiment classification task confusion matrix:

# %%
#Classification Report:
from sklearn.metrics import classification_report
print(classification_report(Ysenti_test, y_senti_pred_top))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.47      0.41      3948
#            1       0.50      0.59      0.54      7608
#            2       0.51      0.47      0.49     11044
#            3       0.70      0.59      0.64     11764
#
#     accuracy                           0.54     34364
#    macro avg       0.52      0.53      0.52     34364
# weighted avg       0.55      0.54      0.54     34364

# %% [markdown]
# # 3. Embeddings as Features

# %% [markdown]
# ## 3.1 Genism.downloader.load

# %%
model = gensim.downloader.load("word2vec-google-news-300")

# %% [markdown]
# ## 3.2 Tokenizer from nltk

# %%
emotion = file[1].tolist()
sentiment = file[2].tolist()

Xemb_train, Xemb_test, Yemb_emo_train, Yemb_emo_test, Yemb_senti_train, Yemb_senti_test  = train_test_split(posts, emotion, sentiment, test_size = 0.2, train_size = 0.8)

# %%
posts_string_train = str(Xemb_train)
tokens = word_tokenize(posts_string_train)

# %%
print("There are "+str(len(tokens))+" tokens in the training set.")
# Out:
# There are 2443608 tokens in the training set.

# %% [markdown]
# ## 3.3 & 3.4 Embedding of reddit posts and Hit rates

# %%
#post embedding for training set

train_hit_rate_lst = []  #to compute the hit rate of training set
word_embeddings = []  #contains words embedding of each post
each_post_embedding_train = [] #contains embeddings of each reddit post as average of embedding of its words (for training set)

for post in Xemb_train:
    for word in post:
        if word in model:
            train_hit_rate_lst.append(word)
            word_embeddings.append(model[word])
        
    each_post_embedding_train.append(np.mean(word_embeddings,axis=0))
    word_embeddings.clear() #This will clear the previous post embedding
# Out:
# c:\python3.8\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\python3.8\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#hit rate for training set

total_words_train = []

for post in Xemb_train:
    for word in post:
        total_words_train.append(word)

hit_rate_train = (len(train_hit_rate_lst)/len(total_words_train)) * 100
print("The hit rate of words (with Word2Vec model) in training set of reddit posts is " + str(round(hit_rate_train)) + "%.")
# Out:
# The hit rate of words (with Word2Vec model) in training set of reddit posts is 73%.

# %%
#post embedding for test set

test_hit_rate_lst = []  #to compute the hit rate of test set
word_embeddings = []  #contains words embedding of each post
each_post_embedding_test = [] #contains embeddings of each reddit post as average of embedding of its words (for test set)

for post in Xemb_test:
    for word in post:
        if word in model:
            test_hit_rate_lst.append(word)
            word_embeddings.append(model[word])
        
    each_post_embedding_test.append(np.mean(word_embeddings,axis=0))
    word_embeddings.clear() #This will clear the previous post embedding

# %%
#hit rate for test set

total_words_test = []

for post in Xemb_test:
    for word in post:
        total_words_test.append(word)

hit_rate_test = (len(test_hit_rate_lst)/len(total_words_test)) * 100
print("The hit rate of words (with Word2Vec model) in test set of reddit posts is " + str(round(hit_rate_test)) + "%.")
# Out:
# The hit rate of words (with Word2Vec model) in test set of reddit posts is 73%.
